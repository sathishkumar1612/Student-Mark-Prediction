# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("student_portuguese_clean.csv")

# %%
df.head()
# Out:
#    student_id school sex  age address_type              family_size  \
# 0           1     GP   F   18        Urban           Greater than 3
# 1           2     GP   F   17        Urban           Greater than 3
# 2           3     GP   F   15        Urban  Less than or equal to 3
# 3           4     GP   F   15        Urban           Greater than 3
# 4           5     GP   F   16        Urban           Greater than 3
#
#      parent_status               mother_education  \
# 0            Apart               higher education
# 1  Living together  primary education (4th grade)
# 2  Living together  primary education (4th grade)
# 3  Living together               higher education
# 4  Living together            secondary education
#
#                 father_education mother_job  ... family_relationship  \
# 0               higher education    at_home  ...                   4
# 1  primary education (4th grade)    at_home  ...                   5
# 2  primary education (4th grade)    at_home  ...                   4
# 3               5th to 9th grade     health  ...                   3
# 4            secondary education      other  ...                   4
#
#   free_time social weekday_alcohol weekend_alcohol  health absences grade_1  \
# 0         3      4               1               1       3        4       0
# 1         3      3               1               1       3        2       9
# 2         3      2               2               3       3        6      12
# 3         2      2               1               1       5        0      14
# 4         3      2               1               2       5        0      11
#
#   grade_2 final_grade
# 0      11          11
# 1      11          11
# 2      13          12
# 3      14          14
# 4      13          13
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['student_id', 'school', 'sex', 'age', 'address_type', 'family_size',
#        'parent_status', 'mother_education', 'father_education', 'mother_job',
#        'father_job', 'school_choice_reason', 'guardian', 'travel_time',
#        'study_time', 'class_failures', 'school_support', 'family_support',
#        'extra_paid_classes', 'activities', 'nursery_school', 'higher_ed',
#        'internet_access', 'romantic_relationship', 'family_relationship',
#        'free_time', 'social', 'weekday_alcohol', 'weekend_alcohol', 'health',
#        'absences', 'grade_1', 'grade_2', 'final_grade'],
#       dtype='object')

# %%
df.shape
# Out:
# (649, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             649 non-null    int64
#  1   school                 649 non-null    object
#  2   sex                    649 non-null    object
#  3   age                    649 non-null    int64
#  4   address_type           649 non-null    object
#  5   family_size            649 non-null    object
#  6   parent_status          649 non-null    object
#  7   mother_education       649 non-null    object
#  8   father_education       649 non-null    object
#  9   mother_job             649 non-null    object
#  10  father_job             649 non-null    object
#  11  school_choice_reason   649 non-null    object
#  12  guardian               649 non-null    object
#  13  travel_time            649 non-null    object
#  14  study_time             649 non-null    object
#  15  class_failures         649 non-null    int64
#  16  school_support         649 non-null    object
#  17  family_support         649 non-null    object
#  18  extra_paid_classes     649 non-null    object
#  19  activities             649 non-null    object
#  20  nursery_school         649 non-null    object
#  21  higher_ed              649 non-null    object
#  22  internet_access        649 non-null    object
#  23  romantic_relationship  649 non-null    object
#  24  family_relationship    649 non-null    int64
#  25  free_time              649 non-null    int64
#  26  social                 649 non-null    int64
#  27  weekday_alcohol        649 non-null    int64
#  28  weekend_alcohol        649 non-null    int64
#  29  health                 649 non-null    int64
#  30  absences               649 non-null    int64
#  31  grade_1                649 non-null    int64
#  32  grade_2                649 non-null    int64
#  33  final_grade            649 non-null    int64
# dtypes: int64(13), object(21)
# memory usage: 172.5+ KB

# %%
df.describe().round(2)
# Out:
#        student_id     age  class_failures  family_relationship  free_time  \
# count      649.00  649.00          649.00               649.00     649.00
# mean       325.00   16.74            0.22                 3.93       3.18
# std        187.49    1.22            0.59                 0.96       1.05
# min          1.00   15.00            0.00                 1.00       1.00
# 25%        163.00   16.00            0.00                 4.00       3.00
# 50%        325.00   17.00            0.00                 4.00       3.00
# 75%        487.00   18.00            0.00                 5.00       4.00
# max        649.00   22.00            3.00                 5.00       5.00
#
#        social  weekday_alcohol  weekend_alcohol  health  absences  grade_1  \
# count  649.00           649.00           649.00  649.00    649.00   649.00
# mean     3.18             1.50             2.28    3.54      3.66    11.40
# std      1.18             0.92             1.28    1.45      4.64     2.75
# min      1.00             1.00             1.00    1.00      0.00     0.00
# 25%      2.00             1.00             1.00    2.00      0.00    10.00
# 50%      3.00             1.00             2.00    4.00      2.00    11.00
# 75%      4.00             2.00             3.00    5.00      6.00    13.00
# max      5.00             5.00             5.00    5.00     32.00    19.00
#
#        grade_2  final_grade
# count   649.00       649.00
# mean     11.57        11.91
# std       2.91         3.23
# min       0.00         0.00
# 25%      10.00        10.00
# 50%      11.00        12.00
# 75%      13.00        14.00
# max      19.00        19.00

# %%
df['final_grade'].value_counts().sort_index()
# Out:
# final_grade
# 0      15
# 1       1
# 5       1
# 6       3
# 7      10
# 8      35
# 9      35
# 10     97
# 11    104
# 12     72
# 13     82
# 14     63
# 15     49
# 16     36
# 17     29
# 18     15
# 19      2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %%
plt.hist(df['final_grade'],color='#E6E6FA')
plt.xlabel("Final Grades")
plt.ylabel("Number of Students ")
#plt.xticks(range(0,20,2))
plt.title("Distribution of Marks ")
plt.show()

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['school', 'sex', 'address_type', 'family_size', 'parent_status',
#        'mother_education', 'father_education', 'mother_job', 'father_job',
#        'school_choice_reason', 'guardian', 'travel_time', 'study_time',
#        'school_support', 'family_support', 'extra_paid_classes', 'activities',
#        'nursery_school', 'higher_ed', 'internet_access',
#        'romantic_relationship'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for column in df.select_dtypes(include="object").columns:
    df[column]=le.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             649 non-null    int64
#  1   school                 649 non-null    int64
#  2   sex                    649 non-null    int64
#  3   age                    649 non-null    int64
#  4   address_type           649 non-null    int64
#  5   family_size            649 non-null    int64
#  6   parent_status          649 non-null    int64
#  7   mother_education       649 non-null    int64
#  8   father_education       649 non-null    int64
#  9   mother_job             649 non-null    int64
#  10  father_job             649 non-null    int64
#  11  school_choice_reason   649 non-null    int64
#  12  guardian               649 non-null    int64
#  13  travel_time            649 non-null    int64
#  14  study_time             649 non-null    int64
#  15  class_failures         649 non-null    int64
#  16  school_support         649 non-null    int64
#  17  family_support         649 non-null    int64
#  18  extra_paid_classes     649 non-null    int64
#  19  activities             649 non-null    int64
#  20  nursery_school         649 non-null    int64
#  21  higher_ed              649 non-null    int64
#  22  internet_access        649 non-null    int64
#  23  romantic_relationship  649 non-null    int64
#  24  family_relationship    649 non-null    int64
#  25  free_time              649 non-null    int64
#  26  social                 649 non-null    int64
#  27  weekday_alcohol        649 non-null    int64
#  28  weekend_alcohol        649 non-null    int64
#  29  health                 649 non-null    int64
#  30  absences               649 non-null    int64
#  31  grade_1                649 non-null    int64
#  32  grade_2                649 non-null    int64
#  33  final_grade            649 non-null    int64
# dtypes: int64(34)
# memory usage: 172.5 KB

# %%
df.head()
# Out:
#    student_id  school  sex  age  address_type  family_size  parent_status  \
# 0           1       0    0   18             1            0              0
# 1           2       0    0   17             1            0              1
# 2           3       0    0   15             1            1              1
# 3           4       0    0   15             1            0              1
# 4           5       0    0   16             1            0              1
#
#    mother_education  father_education  mother_job  ...  family_relationship  \
# 0                 1                 1           0  ...                    4
# 1                 3                 3           0  ...                    5
# 2                 3                 3           0  ...                    4
# 3                 1                 0           1  ...                    3
# 4                 4                 4           2  ...                    4
#
#    free_time  social  weekday_alcohol  weekend_alcohol  health  absences  \
# 0          3       4                1                1       3         4
# 1          3       3                1                1       3         2
# 2          3       2                2                3       3         6
# 3          2       2                1                1       5         0
# 4          3       2                1                2       5         0
#
#    grade_1  grade_2  final_grade
# 0        0       11           11
# 1        9       11           11
# 2       12       13           12
# 3       14       14           14
# 4       11       13           13
#
# [5 rows x 34 columns]

# %%
x=df.drop('final_grade',axis=1)

# %%
y=df['final_grade']

# %%
print(x.shape)
print(y.shape)
# Out:
# (649, 33)
# (649,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (519, 33)
# (130, 33)
# (519,)
# (130,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print(y_pred[:10])
# Out:
# [18.29772832 11.89378836 18.18523597 11.23681501 11.90850665 16.18686053
#  17.65001833  9.1044443  11.10773516 10.63220641]

# %%
comparison=pd.DataFrame({
    "Actual value":y_test,
    "Predicted value": y_pred
})
comparison.head(15)
# Out:
#      Actual value  Predicted value
# 636            19        18.297728
# 220            12        11.893788
# 594            18        18.185236
# 429            11        11.236815
# 72             11        11.908507
# 448            17        16.186861
# 181            18        17.650018
# 131             8         9.104444
# 231            10        11.107735
# 277            11        10.632206
# 606            18        18.130678
# 281            11        12.161754
# 249            12        12.326208
# 81              9         9.292427
# 463            12        11.333794

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
print("MAE:", mae)
# Out:
# MAE: 0.7488814769148586

# %%
mse=mean_squared_error(y_test,y_pred)
print("MSE:",mse)
# Out:
# MSE: 1.4526854090898718

# %%
rmse=mean_squared_error(y_test,y_pred)** 0.5
print("RMSE : ",rmse)
# Out:
# RMSE :  1.205273997516694

# %%
r2=r2_score(y_test,y_pred)
print("R2 : ",r2)
# Out:
# R2 :  0.8510328425668137

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred,marker='*')
plt.xlabel("Actual Marks")
plt.ylabel("Predicted Marks")
plt.title("Actual vs Predicted Marks")
plt.show()

# %%
df.corr()['final_grade'].sort_values(ascending=False)
# Out:
# final_grade              1.000000
# grade_2                  0.918548
# grade_1                  0.826387
# higher_ed                0.332172
# address_type             0.167637
# internet_access          0.150025
# mother_job               0.148252
# school_choice_reason     0.124969
# travel_time              0.081775
# family_relationship      0.063361
# activities               0.059791
# family_support           0.059206
# father_job               0.052953
# family_size              0.045016
# nursery_school           0.028752
# parent_status           -0.000754
# father_education        -0.036996
# extra_paid_classes      -0.054898
# school_support          -0.066405
# guardian                -0.079609
# mother_education        -0.081282
# social                  -0.087641
# romantic_relationship   -0.090583
# absences                -0.091379
# study_time              -0.095489
# health                  -0.098851
# age                     -0.106505
# free_time               -0.122705
# sex                     -0.129077
# weekend_alcohol         -0.176619
# student_id              -0.176843
# weekday_alcohol         -0.204719
# school                  -0.284294
# class_failures          -0.393316
# Name: final_grade, dtype: float64

# %%
import seaborn as sns 
sns.heatmap(df.corr(),cmap='coolwarm')
plt.show()

# %%
import joblib 

joblib.dump(model,'student_mark_prediction_model')
# Out:
# ['student_mark_prediction_model']
